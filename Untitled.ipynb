# %%
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\Erik\Documents\realtime projects Datascience\SQL projects\FMGC\C9_Input_Files\dataset\dim_campaigns.csv")
df_1= pd.read_csv(r"C:\Users\Erik\Documents\realtime projects Datascience\SQL projects\FMGC\C9_Input_Files\dataset\dim_products.csv")
df_2= pd.read_csv(r"C:\Users\Erik\Documents\realtime projects Datascience\SQL projects\FMGC\C9_Input_Files\dataset\dim_stores.csv")
df_3= pd.read_csv(r"C:\Users\Erik\Documents\realtime projects Datascience\SQL projects\FMGC\C9_Input_Files\dataset\fact_events.csv")

# %%
df_1
# Out:
#    product_code                               product_name           category
# 0           P01                     Atliq_Masoor_Dal (1KG)  Grocery & Staples
# 1           P02               Atliq_Sonamasuri_Rice (10KG)  Grocery & Staples
# 2           P03                    Atliq_Suflower_Oil (1L)  Grocery & Staples
# 3           P04               Atliq_Farm_Chakki_Atta (1KG)  Grocery & Staples
# 4           P05            Atliq_Scrub_Sponge_For_Dishwash          Home Care
# 5           P06            Atliq_Fusion_Container_Set_of_3          Home Care
# 6           P09  Atliq_Body_Milk_Nourishing_Lotion (120ML)      Personal Care
# 7           P10    Atliq_Cream_Beauty_Bathing_Soap (125GM)      Personal Care
# 8           P13                Atliq_High_Glo_15W_LED_Bulb    Home Appliances
# 9           P14             Atliq_waterproof_Immersion_Rod    Home Appliances
# 10          P11      Atliq_Doodh_Kesar_Body_Lotion (200ML)      Personal Care
# ...

# %%
mergeddata=df_3.merge(right = df, on = 'campaign_id')

# %%
df4 = pd.merge(pd.merge(mergeddata,df_1,on='product_code', how='left'),df_3,on='store_id', how='left')

# %%
df4
# Out:
#       event_id_x store_id campaign_id_x product_code_x  base_price_x  \
# 0         7f650b  STCBE-2   CAMP_SAN_01            P11           190
# 1         7f650b  STCBE-2   CAMP_SAN_01            P11           190
# 2         7f650b  STCBE-2   CAMP_SAN_01            P11           190
# 3         7f650b  STCBE-2   CAMP_SAN_01            P11           190
# 4         7f650b  STCBE-2   CAMP_SAN_01            P11           190
# ...          ...      ...           ...            ...           ...
# 44995     a9ae21  STCBE-0   CAMP_DIW_01            P12            62
# 44996     a9ae21  STCBE-0   CAMP_DIW_01            P12            62
# 44997     a9ae21  STCBE-0   CAMP_DIW_01            P12            62
# 44998     a9ae21  STCBE-0   CAMP_DIW_01            P12            62
# 44999     a9ae21  STCBE-0   CAMP_DIW_01            P12            62
#
#       promo_type_x  quantity_sold(before_promo)_x  \
# 0          50% OFF                             34
# ...

# %%
df_2
# Out:
#    store_id           city
# 0   STTRV-0     Trivandrum
# 1   STMDU-3        Madurai
# 2   STHYD-6      Hyderabad
# 3   STVSK-1  Visakhapatnam
# 4   STCBE-3     Coimbatore
# 5   STBLR-8      Bengaluru
# 6   STBLR-2      Bengaluru
# 7   STCHE-7        Chennai
# 8   STCBE-0     Coimbatore
# 9   STVSK-0  Visakhapatnam
# 10  STCHE-5        Chennai
# 11  STHYD-5      Hyderabad
# 12  STMDU-1        Madurai
# 13  STVJD-0     Vijayawada
# 14  STMDU-2        Madurai
# 15  STMYS-3         Mysuru
# 16  STMLR-0      Mangalore
# 17  STVSK-4  Visakhapatnam
# 18  STCHE-3        Chennai
# 19  STCHE-6        Chennai
# 20  STBLR-6      Bengaluru
# 21  STCBE-2     Coimbatore
# 22  STMLR-1      Mangalore
# 23  STCHE-2        Chennai
# 24  STCHE-1        Chennai
# 25  STBLR-5      Bengaluru
# 26  STMYS-0         Mysuru
# 27  STMDU-0        Madurai
# 28  STBLR-9      Bengaluru
# 29  STVSK-2  Visakhapatnam
# 30  STTRV-1     Trivandrum
# 31  STBLR-3      Bengaluru
# 32  STHYD-0      Hyderabad
# ...
